# %%
import pandas as pd

# %%
pd1 = pd.read_csv("./book_recommendations_list_v1.csv")

# %%
pd1
# Out:
#       Unnamed: 0                                         book_title  \
# 0              0                              Count of Monte Cristo
# 1              1                              Letters of Two Brides
# 2              2                                        Bleak House
# 3              3                                     Penguin Island
# 4              4                              This Side of Paradise
# ...          ...                                                ...
# 4041        4041  United Kingdom House of Commons Speeches Colle...
# 4042        4042                              Three Girls in a Flat
# 4043        4043                                       First Violin
# 4044        4044                               Art of Money Getting
# 4045        4045                                     Breaking Point
#
#                                book_recommendation_urls
# 0     ['https://librivox.org/bleak-house-by-charles-...
# ...

# %%
pd2 = pd.read_csv("./book_recommendations_list_v1_2nd_half.csv")

# %%
pd2
# Out:
#       Unnamed: 0                                         book_title  \
# 0              0  Book of a Thousand Nights and a Night (Arabian...
# 1              1                              Makers of Many Things
# 2              2    Beric the Briton: a Story of the Roman Invasion
# 3              3                               Our Journey to Sinai
# 4              4                       Chemical History of A Candle
# ...          ...                                                ...
# 4933        4933                                      Modern Essays
# 4934        4934                      Rainy Week (Dramatic Reading)
# 4935        4935                      Bible Passages Collection 001
# 4936        4936                 Astounding Stories 20, August 1931
# 4937        4937                         Little Prudy's Sister Susy
#
#                                book_recommendation_urls
# 0     ['https://librivox.org/the-importance-of-being...
# ...

# %%
concate_recs = pd.concat([pd1,pd2])
concate_recs
# Out:
#       Unnamed: 0                          book_title  \
# 0              0               Count of Monte Cristo
# 1              1               Letters of Two Brides
# 2              2                         Bleak House
# 3              3                      Penguin Island
# 4              4               This Side of Paradise
# ...          ...                                 ...
# 4933        4933                       Modern Essays
# 4934        4934       Rainy Week (Dramatic Reading)
# 4935        4935       Bible Passages Collection 001
# 4936        4936  Astounding Stories 20, August 1931
# 4937        4937          Little Prudy's Sister Susy
#
#                                book_recommendation_urls
# 0     ['https://librivox.org/bleak-house-by-charles-...
# 1     ['https://librivox.org/unbeaten-tracks-in-japa...
# 2     ['https://librivox.org/bleak-house-by-charles-...
# 3     ['https://librivox.org/the-getting-of-wisdom-b...
# ...

# %%
concate_recs.to_csv("combined_reccomendations_v1.csv")
